# %%
import math
sqrt_value = math.sqrt(144)
pi_value = math.pi
print("Square root of 144:", sqrt_value)
print("Value of pi:", pi_value)
# Out:
# Square root of 144: 12.0
# Value of pi: 3.141592653589793

# %%
from random import randint
ran_num = randint(1, 100)
print("Random nos:", ran_num)
# Out:
# Random nos: 16

# %%
import os
print("file location:")
print(os.__file__)
print("\nAll available functions:")
print(dir(os))
# Out:
# file location:
# /usr/lib/python3.12/os.py
#
# All available functions:
# ...

# %%
try:
    import non_existent_module
    print("Module imported successfully!")
except ModuleNotFoundError:
    print("Module not found. Using fallback mechanism.")
    class FallbackModule:
        def greet(self):
            return "Using fallback functionality."
    fallback = FallbackModule()
    print(fallback.greet())
# Out:
# Module not found. Using fallback mechanism.
# Using fallback functionality.
